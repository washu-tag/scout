# %% [markdown]
# # Quality & Turnaround Time Dashboard
#
# Monitor radiology report quality and TAT metrics.
#
# **Table:** `default.latest_reports` (deduplicated, last year, ~2M reports)
#
# **Metrics:**
# - Turnaround time by modality, trends over time
# - Radiologist performance and productivity
# - Report completeness (findings, impression, addendum)

# %%
from quality_metrics_dashboard import create_landing_page

# Launch dashboard with instant page load
# Data loads only when "Launch Dashboard" button is clicked
create_landing_page(
    table_name="default.latest_reports",  # Deduplicated, fast
    date_range_days=None                   # All available data (last year)
)
